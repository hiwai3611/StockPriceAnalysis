# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from fbprophet import Prophet

df = pd.read_csv("nikkei_kabuka2.csv")
df.tail()
# Out:
#              ds         y
# 972  2013/01/10  10652.64
# 973  2013/01/09  10578.57
# 974  2013/01/08  10508.06
# 975  2013/01/07  10599.01
# 976  2013/01/04  10688.11

# %%
df['y'] = np.log(df['y'])
#df.tail()

m = Prophet()
m.fit(df);

future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1337 2018-05-26
# 1338 2018-05-27
# 1339 2018-05-28
# 1340 2018-05-29
# 1341 2018-05-30

# %%
forecast = m.predict(future)
m.plot(forecast);

# %%
m.plot_components(forecast);

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from fbprophet import Prophet

df = pd.read_csv("C:/Users/h-iwai/Documents/kabu/nikkei_kabuka2.csv")
df['y'] = np.log(df['y'])
#df.tail()

m = Prophet()
m.fit(df);

future = m.make_future_dataframe(periods=365)

forecast = m.predict(future)
m.plot(forecast);

# %%
m.plot_components(forecast);
